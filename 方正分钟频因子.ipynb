# %%
from MinuteFrequentFactorFZ import MinFreqFactor
from MinuteFrequentFactorCalculateMethodsFZ import *

# %% [markdown]
# 适度冒险

# %%
YaoYanBoDongLv = MinFreqFactor('YaoYanBoDongLv')
YaoYanBoDongLv.cal_exposure_by_min_data(
    cal_YaoYanBoDongLv,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
YaoYanBoDongLv.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
YaoYanShouYiLv = MinFreqFactor('YaoYanShouYiLv')
YaoYanShouYiLv.cal_exposure_by_min_data(
    cal_YaoYanShouYiLv,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
YaoYanShouYiLv.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
ShiDuMaoXian = MinFreqFactor('ShiDuMaoXian')
ShiDuMaoXian.cal_exposure_by_intermediate(
    cal_ShiDuMaoXian,
    ['YaoYanShouYiLv', 'YaoYanBoDongLv'],
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
ShiDuMaoXian.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
ShiDuMaoXian.coverage()
ShiDuMaoXian.ic_test(plot_out=True)
ShiDuMaoXian.group_test(weight_param='tmc')

# %% [markdown]
# 潮汐因子

# %%
QiangShiBanChaoXi = MinFreqFactor('QiangShiBanChaoXi')
QiangShiBanChaoXi.cal_exposure_by_min_data(
    cal_QiangShiBanChaoXi,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
QiangShiBanChaoXi.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
RuoShiBanChaoXi = MinFreqFactor('RuoShiBanChaoXi')
RuoShiBanChaoXi.cal_exposure_by_min_data(
    cal_RuoShiBanChaoXi,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
RuoShiBanChaoXi.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
ChaoXi = MinFreqFactor('ChaoXi')
ChaoXi.cal_exposure_by_intermediate(
    cal_ChaoXi,
    ['QiangShiBanChaoXi', 'RuoShiBanChaoXi'],
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
ChaoXi.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
ChaoXi.coverage()
ChaoXi.ic_test()
ChaoXi.group_test(weight_param='tmc')

# %% [markdown]
# 云开雾散

# %%
MoHuGuanLianDu = MinFreqFactor('MoHuGuanLianDu')
MoHuGuanLianDu.cal_exposure_by_min_data(
    cal_MoHuGuanLianDu,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
MoHuGuanLianDu.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
MoHuJinEBi = MinFreqFactor('MoHuJinEBi')
MoHuJinEBi.cal_exposure_by_min_data(
    cal_MoHuJinEBi,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
MoHuJinEBi.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
MoHuJiaCha = MinFreqFactor('MoHuJiaCha')
MoHuJiaCha.cal_exposure_by_min_data(
    cal_MoHuJiaCha,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
MoHuJiaCha.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
YunKaiWuSan = MinFreqFactor('YunKaiWuSan')
YunKaiWuSan.cal_exposure_by_intermediate(
    cal_YunKaiWuSan,
    ['MoHuGuanLianDu', 'MoHuJinEBi', 'MoHuJiaCha'],
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
YunKaiWuSan.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
YunKaiWuSan.coverage()
YunKaiWuSan.ic_test()
YunKaiWuSan.group_test(weight_param='tmc')

# %% [markdown]
# 勇攀高峰

# %%
PanDeng = MinFreqFactor('PanDeng')
PanDeng.cal_exposure_by_min_data(
    cal_PanDeng,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
PanDeng.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
YongPanGaoFeng = MinFreqFactor('YongPanGaoFeng')
YongPanGaoFeng.cal_exposure_by_intermediate(
    cal_YongPanGaoFeng,
    'PanDeng',
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
YongPanGaoFeng.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
YongPanGaoFeng.coverage()
YongPanGaoFeng.ic_test()
YongPanGaoFeng.group_test(weight_param='tmc')

# %% [markdown]
# 飞蛾扑火

# %%
TiaoYueDu = MinFreqFactor('TiaoYueDu')
TiaoYueDu.cal_exposure_by_min_data(cal_TiaoYueDu,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
TiaoYueDu.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
FeiEPuHuo = MinFreqFactor('FeiEPuHuo')
FeiEPuHuo.cal_exposure_by_intermediate(
    cal_FeiEPuHuo,
    'TiaoYueDu',
    need_daily_pv_data=True,
    depend_columns=['code', 'date', 'high', 'low', 'close'],
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
FeiEPuHuo.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
FeiEPuHuo.coverage()
FeiEPuHuo.ic_test()
FeiEPuHuo.group_test(weight_param='tmc')

# %% [markdown]
# 水中行舟

# %%
GuYanChuQun = MinFreqFactor('GuYanChuQun')
GuYanChuQun.cal_exposure_by_min_data(
    cal_GuYanChuQun,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
GuYanChuQun.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
GaoDiECha = MinFreqFactor('GaoDiECha')
GaoDiECha.cal_exposure_by_min_data(
    cal_GaoDiECha,
    need_daily_data=True,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
GaoDiECha.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
SuiBoZhuLiu = MinFreqFactor('SuiBoZhuLiu')
SuiBoZhuLiu.cal_exposure_by_intermediate(
    cal_SuiBoZhuLiu,
    'GaoDiECha',
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
SuiBoZhuLiu.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
# Out:
# Processing: 0it [00:00, ?it/s]

# %%
ShuiZhongXingZhou = MinFreqFactor('ShuiZhongXingZhou')
ShuiZhongXingZhou.cal_exposure_by_intermediate(
    cal_ShuiZhongXingZhou,
    ['GuYanChuQun', 'SuiBoZhuLiu'],
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
ShuiZhongXingZhou.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
ShuiZhongXingZhou.coverage()
ShuiZhongXingZhou.ic_test()
ShuiZhongXingZhou.group_test(weight_param='tmc')

# %% [markdown]
# 花隐林间

# %%
ZhaoMoChenWu = MinFreqFactor('ZhaoMoChenWu')
ZhaoMoChenWu.cal_exposure_by_min_data(
    cal_ZhaoMoChenWu,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor',
    n_jobs=8
)
ZhaoMoChenWu.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
WuBiGuMu = MinFreqFactor('WuBiGuMu')
WuBiGuMu.cal_exposure_by_min_data(
    cal_WuBiGuMu,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor',
    n_jobs=6
)
WuBiGuMu.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
YeMianShuangLu_t_intercept = MinFreqFactor('YeMianShuangLu_t_intercept')
YeMianShuangLu_t_intercept.cal_exposure_by_min_data(
    cal_YeMianShuangLu_t_intercept,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor',
    n_jobs=8
)
YeMianShuangLu_t_intercept.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
YeMianShuangLu = MinFreqFactor('YeMianShuangLu')
YeMianShuangLu.cal_exposure_by_intermediate(
    cal_YeMianShuangLu,
    'YeMianShuangLu_t_intercept',
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
YeMianShuangLu.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
# Out:
# Processing: 0it [00:00, ?it/s]

# %%
HuaYinLinJian = MinFreqFactor('HuaYinLinJian')
HuaYinLinJian.cal_exposure_by_intermediate(
    cal_HuaYinLinJian,
    ['ZhaoMoChenWu', 'WuBiGuMu', 'YeMianShuangLu'],
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
HuaYinLinJian.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
HuaYinLinJian.coverage()
HuaYinLinJian.ic_test()
HuaYinLinJian.group_test(weight_param='tmc')

# %% [markdown]
# 待著而救

# %%
GenSuiXiShu = MinFreqFactor('GenSuiXiShu')
GenSuiXiShu.cal_exposure_by_min_data(
    cal_GenSuiXiShu,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
GenSuiXiShu.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
DaiZhuErJiu = MinFreqFactor('DaiZhuErJiu')
DaiZhuErJiu.cal_exposure_by_intermediate(
    cal_DaiZhuErJiu,
    'GenSuiXiShu',
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
DaiZhuErJiu.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
DaiZhuErJiu.coverage()
DaiZhuErJiu.ic_test()
DaiZhuErJiu.group_test(weight_param='tmc')

# %% [markdown]
# 多空博弈

# %%
ChengJiaoLiangBoYi_ShouYiLv = MinFreqFactor('ChengJiaoLiangBoYi_ShouYiLv')
ChengJiaoLiangBoYi_ShouYiLv.cal_exposure_by_min_data(
    cal_ChengJiaoLiangBoYi_ShouYiLv,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
ChengJiaoLiangBoYi_ShouYiLv.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
ChengJiaoLiangBoYi_RiNeiXiangDuiWeiZhi = MinFreqFactor('ChengJiaoLiangBoYi_RiNeiXiangDuiWeiZhi')
ChengJiaoLiangBoYi_RiNeiXiangDuiWeiZhi.cal_exposure_by_min_data(
    cal_ChengJiaoLiangBoYi_RiNeiXiangDuiWeiZhi,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
ChengJiaoLiangBoYi_RiNeiXiangDuiWeiZhi.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
ZhenFuBoYi = MinFreqFactor('ZhenFuBoYi')
ZhenFuBoYi.cal_exposure_by_min_data(
    cal_ZhenFuBoYi,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
ZhenFuBoYi.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
DuoKongBoYi = MinFreqFactor('DuoKongBoYi')
DuoKongBoYi.cal_exposure_by_intermediate(
    cal_DuoKongBoYi,
    [
        'ChengJiaoLiangBoYi_ShouYiLv',
        'ChengJiaoLiangBoYi_RiNeiXiangDuiWeiZhi',
        'ZhenFuBoYi'
    ],
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
DuoKongBoYi.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
DuoKongBoYi.coverage()
DuoKongBoYi.ic_test()
DuoKongBoYi.group_test(weight_param='tmc')

# %% [markdown]
# 协同效应

# %%
ChengJiaoLiangXieTong = MinFreqFactor('ChengJiaoLiangXieTong')
ChengJiaoLiangXieTong.cal_exposure_by_min_data(
    cal_ChengJiaoLiangXieTong,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
ChengJiaoLiangXieTong.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
XieTongJiaCha = MinFreqFactor('XieTongJiaCha')
XieTongJiaCha.cal_exposure_by_min_data(
    cal_XieTongJiaCha,
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
XieTongJiaCha.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)

# %%
XieTongXiaoYing = MinFreqFactor('XieTongXiaoYing')
XieTongXiaoYing.cal_exposure_by_intermediate(
    cal_XieTongXiaoYing,
    ['ChengJiaoLiangXieTong', 'XieTongJiaCha'],
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor',
    intermediate_path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Intermediate Factor'
)
XieTongXiaoYing.to_parquet(
    path=r'D:\QuantData\MinuteFreqFactor\FangZheng Factor\Final Factor'
)

# %%
XieTongXiaoYing.coverage()
XieTongXiaoYing.ic_test()
XieTongXiaoYing.group_test(weight_param='tmc')
